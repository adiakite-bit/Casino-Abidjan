# %%
# Game BLACK JACK Set up 
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three' , 'Four' , 'Five', 'Six', 'Seven' , 'Eight'  , 'Nine' , 'Ten' ,
         'Jack' , 'Queen' , 'King'  , 'Ace'  )

drink_descs = ('Jack Daniels' , 'Smirtnoff', 'Coca cola', 'Water')

drink_prices = {'Jack Daniels' : 50 , 'Smirtnoff' : 45 , 'Coca cola' : 5 , 'Water' : 2 }


values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

# %%
class Card:
    def __init__(self,suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    
    def __str__(self):
        return self.rank + ' of ' + self.suit
    
#     def save_card(self,value):
#         self.value = value
#         saved_cards = {}
        
#         for suit in suit:
#             for rank in ranks:
#                 saved_card[self.value] = values[rank]

# %%
### Create a Deck class
class Deck:
    
    def __init__(self):
        
        self.all_cards = []
        
        #self.players_combination = []
        for suit in suits:
            for rank in ranks:
                
                #create the card Object
                created_card = Card(suit,rank)
                #print(created_card.rank)
                self.all_cards.append(created_card)
                #self.players_combination.append(created_card)
    
    
    def shuffle(self):
        
        random.shuffle(self.all_cards)
    
    def deal_one(self):
    
        return self.all_cards.pop()
#         view = Card(this_card.suit,this_card.rank)
#         print(view)
       
    
#     def __str__(self):
#         return self.rank + ' of ' + self.suit

# %%
class Player:
    
    def __init__(self,name,account_balance,drink,type_drink,vacc):
        
        
        self.name = name
        self.account_balance = account_balance
        self.drink = drink
        self.type_drink = type_drink
        self.vacc  = vacc
        
        
        
    def remove_one(self):
        return self.all_cards.pop(0)
    
    def add_cards(self, new_cards):
        if type(new_cards) == type([]):
        #List of multiple Card Object
            self.all_cards.extend(new_cards)
        else:
            #For a single card Object 
            self.all_cards.append(new_cards)
    
    def add_balance(self,value):
        self.account_balance = self.account_balance + value
        return  f'Player {self.name}, your new balance is now {str(self.account_balance)}$'    
        
    def reduce_balance(self,value):
        self.account_balance = self.account_balance - value
        return  f'Player {self.name}, your new balance is now {str(self.account_balance)}$'
    
             
    def __str__(self):
        return f'Player {self.name} has {len(self.cards)} cards.'

# %%
class Hand(Player):
    def __init__(self):
        self.cards = []  # start with an empty list as we did in the Deck class
        self.current_hand = []
        
        
#             for player_suit in suits:
#             if player_suit == suit:
#                     for rank in ranks:
        
        self.value = 0   # start with zero value

            

        self.aces = 0    # add an attribute to keep track of aces
    
    def add_card(self,card):
        self.cards.append(card)
            
        for card in self.cards:
            if card.rank =='Ace':
                ace_on = True
                print('Ace is true')
#                 if ace_on == False:
#                         break
                while ace_on:
                    try:
                        pick = int(input('Would you value of 1 or 11  ? '))
                        if pick == 1:
                            print('Adding ' + card.suit + ' of ' + card.rank +' value of ' + str(pick) + '\n')
                            self.value += pick
                            self.aces += 1
                            self.current_hand.append(self.cards.pop())
                            ace_on = False
                            break
                        
                        elif pick == 11:
                            print('Adding ' + card.suit + ' of ' + card.rank +' value of ' + str(pick) + '\n')
                            self.value += pick
                            self.aces += 1
                            self.current_hand.append(self.cards.pop())
                            ace_on = False
                            break
                    

                    except:
                        print('You must pick in between 1 or 11 ' + '\n')
                        break
            else:
                print('Adding ' + card.suit + ' of ' + card.rank +' value of ' + str(values[card.rank]) + '\n')
                self.value +=  values[card.rank]
                self.current_hand.append(self.cards.pop())
                
  
                               
      
        pass

    def show_player(self,name,balance):
        return f'Player {name} has {len(self.current_hand)} cards. value of {self.value}. Bank Account is {balance} $ ' + '\n'
     
    def show_hand(self):
        for card in self.cards:
            print(Card(card.suit,card.rank))
    
    def check_busst(self,name):
        busst = False
        if self.value > 21:
            busst = True
            while busst:
                print('\n')
                print(f'Player {name.title()} just bust with value of {self.value} '  )
                print('\t' + 'Player ' + name.title() + ' just lost ' + '\n' )
                break
        else:
            if busst == True:
                pass
            else: 
                pass
#                 print(f'{name.title()}, you have not bust yet ... Dealer Turn to play ')
#                 print('...' + '\n')
        
        return busst
    def player_value_sum(self):
        return self.value
    
    def reset_player_hand(self):
        self.value = 0
        self.current_hand = []
        
#     def reduce_bet_after_loose(self,bet):
#         bet -= bet
#         return bet
    
#     def increase_bet_after_win(self,bet):
#         bet += bet
#         return

# %%
class Chips():
    
    def __init__(self,total,bet):
        self.total = total  # This can be set to a default value or supplied by a user input
        self.bet = bet
    
        
    def win_bet(self):
        self.total += self.bet
        return self.total
        
        
#         return self.total

        
#         if 
#         pass
    
    def loose_bet(self):
        self.total -= self.bet
        return self.total
#         count_lost += 1
        
#         return self.total

# %%
#Create Player Class
class Computer_dealer:
    
    def __init__(self):
        #Card.__init__(self)
        
 #       self.name = name
        
        self.computer_current_hand  = []
        self.cards  = []
        
        
        self.aces = 0    # add an attribute to keep track of aces
        self.value  = 0
        
    def take_order(self,order):
        if type(player_1.name) != str:
            player = False
        

        else:
            player = True
            if player:
                for drink_desc in drink_descs:
                    for drink_price in drink_prices:
                        if order == drink_desc:
                    #create player_billing_Object
                            player_info = Player(player_1.name,player_1.account_balance,player_1.drink,player_1.type_drink, player_1.vacc)
                            #print(drink_prices[player_info.type_drink])
                            player_1.reduce_balance(drink_prices[player_info.type_drink])
                            break
                        else:
                            pass
        

                        
               #         self.account_balance = self.account_balance + self.drink_price[drink_desc]

    def show_drinks(self):
        print('\n')
        print('Here the list of  Drinks : ' + '\n')
        print('------------------------------------')
        print('------------------------------------'+ '\n')
        print ('Jack Daniels  50$ ' ) 
        print ('Smirtnoff     45$ ') 
        print ('Coca cola      5$ ') 
        print ('Water          2$'  + '\n' )
        print('------------------------------------')
        print('------------------------------------')
        
    def show_rates(self):
        print('Please Note' + '\n')
        print('Here the rates exchange at the end of the Casino game : ' + '\n')
        print('------------------------------------')
        print('------------------------------------'+ '\n')
        print('---- From 0 to 1500 chips -  you triple your Chips  ')
        print('---- From 1500 chips and Above - you double your Chips ')
        print('------------------------------------')
        print('------------------------------------')     
        
        
                    

    
    def add_card(self, new_cards):
        if type(new_cards) == type([]):
        #List of multiple Card Object
            self.all_cards.extend(new_cards)
        else:
            #For a single card Object 
            self.all_cards.append(new_cards)
        
#     def account(self,account_balance):
#         return  f'Player {self.name} has {str(self.account_balance)}$ '

    def add_balance(self,value):
        self.account_balance = self.account_balance + value
        return  f'Player {self.name}, your new balance is now {str(self.account_balance)}$'    
        
    def reduce_balance(self,value):
        self.account_balance = self.account_balance - value
        return  f'Player {self.name}, your new balance is now {str(self.account_balance)}$'
    
    

    def add_dealer_hand_card(self,card):
        self.cards.append(card)
        for card in self.cards:
#             if card.suit in suits:
            ace_on = False
            if card.rank =='Ace':
                ace_on = True
                print('Ace is true')
#                 if ace_on == False:
#                         break
            while ace_on:
                try:
                    choose_check = random.randint(1,11)
                    if choose_check == 1:
                        print('Adding ' + card.suit + ' of ' + card.rank +' value of ' + str(choose_check) + '\n')
                        self.value += choose_check
                        self.aces += 1
                        card_popped = self.cards.pop()
                        self.computer_current_hand.append(card_popped)
                        ace_on = False
                        break
                        
                    elif choose_check == 11:
                        print('Adding ' + card.suit + ' of ' + card.rank +' value of ' + str(choose_check) + '\n')
                        self.value += choose_check
                        self.aces += 1
                        card_popped = self.cards.pop()
                        self.computer_current_hand.append(card_popped)
                        ace_on = False
                        break
                    

                except(ValueError,TypeError):
                    print('Dealer will pick  between 1 or 11 ' + '\n')
                    ace_on = True
                    break
            else:        
#                 print(' Dealer Adding ' + card.suit + ' of ' + card.rank +' value of ' + str(values[card.rank]))
                self.value +=  values[card.rank]
                self.computer_current_hand.append(self.cards.pop())

    def show_dealer_hand(self):
        return f'Dealer has {len(self.computer_current_hand)}  card with value of {self.value} ' + '\n'
     
    def show_hand(self):
        for card in self.cards:
            print(Card(card.suit,card.rank))
    
    def computer_busst(self):
        busst = False
        if self.value > 21:
            busst = True
            while busst:
                print('Dealer computer just bust ' + '\n' )
                print( 'Dealer ' + ' just lost ' + '\n' )
#                 print('' + self.name)
                print('...' + '\n')
                break
        else:
            if busst == True:
                pass
            else:
                pass
#                 print(' Dealer not Bust , player s turn to play now...')
#                 print('...' + '\n')
        
        return busst
    
    def dealer_value_sum(self):
        return self.value
    
    def reset_dealer_hand(self):
        self.value = 0    
        self.computer_current_hand  = []
        

            
#     def __str__(self):
#         return f'Player {self.name} has {len(self.all_cards)} cards.'

# %%
def take_bet(chips):
    
  
    while True:

        try:
            bet = int(input('How many chips Bet for game 1  ')) 
            print('\n')
        except ValueError:
            print('Please choose a  Integer ')
        else:
            if bet > chips:
                print('Hi, ' +' You do not have enough chips, you currently have ' + str(chips) + ' chips'  +'\n')
                
            else:
                break
            
            

    return bet

# %%
def replay():
    replay_anwser = False
    replay_check = True
    while replay_check:
        try:
            q = input('Would you like to continue playing ? Y or N')
            print('\n')
            if q.upper() == 'Y':
                replay_anwser = True
                print('\n' + ' Good luck !' + '\n')
                break
            elif q.upper() == 'N':
                print('Thanks for playing')
                replay_check = False
        except:
            print('You must pick between Y or N ?' + '\n')
    else:
        pass
        
    return replay_anwser

# %%
player_1 = Player('Adou',5000, False,'Coca cola',True)

# %%
balance = player_1.account_balance

# %%
take_bet

# %%
dealer_1.take_order('Jack Daniels')

# %%
player_1.add_balance(45)

# %%
player_1.reduce_balance(45)

# %%
type(player_1.name)
print(player_1)

# %%
client_check = player_1.name

# %%
banned_player_list.append(player_1.name)

# %%
player_1.account_balance

# %%
dealer_1 = Computer_dealer()
banned_player_list

# %%
# print(new_deck.all_cards)
dealer_1 = Computer_dealer()

new_deck = Deck()
new_deck.shuffle()

three_spade = Card('Clubs', 'Ace')


player_1 = Player('Naomie',5000, False,'Water',True )
hand_1 = Hand()




hand_1.add_card(three_spade)
# print(hand_1.show_player('Naomie',5000))
# print(hand_1.show_hand())



hand_1.add_card(new_deck.deal_one())
hand_1.reset_player_hand()
# dealer_1.reset_dealer_hand()

# print(player_1.name + ' has now ' + str(400) + ' chips ' + '\n')

print(hand_1.show_player(player_1.name,player_1.account_balance))

chips = 400
bet = take_bet(chips)
# type(bet)
# print(bet)
chip_1 = Chips(chips,bet)
# chip_1.total
chips = chip_1.win_bet()
chip_1.total


# chips = chip_1.win_bet('abdoul')
# chips

# answer = replay()
# answer

# take_bet(chip_1)

# dealer_1.add_dealer_hand_card(three_spade)
# print(dealer_1.show_dealer_hand())
# print(dealer_1.show_hand())


# print('The last card currently in the deck is' + '\n')
# print( new_deck.deal_one())
# hand_1.add_card(new_deck.deal_one())
# hand_1.add_card(new_deck.deal_one())
# dealer_1.add_dealer_hand_card(new_deck.deal_one())
# hand_1.show_hand()

#hand_1.show_player(player_1.name,player_1.account_balance)
# view = Card('Hearts','Two')
# print(view)
# Out:
# Ace is true
# Would you value of 1 or 11  ? 1
# Adding Clubs of Ace value of 1
#
# Adding Clubs of Three value of 3
#
# Player Naomie has 0 cards. value of 0. Bank Account is 5000 $
#
# How many chips Bet for game 1  200
# 600

# %%
## GAME SET UP

print('---------------------------------------------------------------')
print('Welcome to Black Jack Abidjan 🇨🇮 club 🎰 ♠️♥️♦️♣️! First Édition')
print('---------------------------------------------------------------')

player_1 = Player('Naomie',5000, False,'Coca cola',True )
hand_1 = Hand()




count_game = 0
dealer_1 = Computer_dealer()


balance = player_1.account_balance   
banned_player_list = []     

      
      
     
      
# bid = True

while True:
    try:
        print('---- From 0 to 1500$ - 200 Chips')
        print('---- From 1500 to 3500$ - 500 Chips')
        print('---- After 3500$ - 800 Chips  ----')
        print('                                  ')
        print('                                  ')
        hand_1.show_player(player_1.name,player_1.account_balance)
        ziack = int(input('How much the bid $$ ? '))
        dealer_1.show_rates()
        if ziack > player_1.account_balance:
            print('Not enough Fund...Busst')
            bust_check = True
    #             break
            while bust_check:
                print('Try Again please..')
                print('..')
                print('                   ')
                bust_check = False
                break

            else:
                bust_check = False
                break    
#             else:
#                 pass                     

            
        else:                
            if ziack in list(range(0,1501)):
                chips = 200
                player_1.reduce_balance(ziack)
                    #balance = player_1.account_balance
                print('                                ')
                print('                                ')
                print(hand_1.show_player(player_1.name,player_1.account_balance))
                print(player_1.name + ' has now ' + str(chips) + ' chips ' + '/n')
                break
            elif ziack in list(range(1501,3501)) :
                chips = 500
                player_1.reduce_balance(ziack)
                    #balance = player_1.account_balance
                print('                                ')
                print('                                ')
                print(hand_1.show_player(player_1.name,player_1.account_balance))
                print(player_1.name + ' has now ' + str(chips) + ' chips ' + '/n')
                break
            else:
                chips = 800
                player_1.reduce_balance(ziack)
                    #balance = player_1.account_balance
                print('                                ')
                print('                                ')
                print(hand_1.show_player(player_1.name,player_1.account_balance))
                print(player_1.name + ' has now ' + str(chips) + ' chips ' + '/n')
                break

        
    except (TypeError,ValueError):
        print('We only takes CASH 💵')

#     else:
#         pass
else:
    pass
      
print('Thanks ,see You can visit the Bar - Restaurant for exclusives Offers .                    ')
print('                                                                                          ')
print('                                                                                          ')
print('                                                                                          ')
print('                                                                                          ')
print('                                                                                          ')
print('-------  Important- VACCINATION IS MANDATORY in order to access Establishment -------------')  


vaccination_check = True

while vaccination_check:
#     if vaccination_check == False:
#         break
        # Exclude banned Players
    client_check = player_1.name
    for client in banned_player_list:
        if client  == client_check:
            print('Please , be sure to present the vaxx Pass')
            vaccination_check = False
            break
          
        else:
            
            pass
    try:
        vaccined = input('Are you VAXX ?? *YES* or *NO*')
        if vaccined.upper() =='YES':
            print('Thanks, you can continue view our specials !! ⇢⇢ 🦞' + '\n')
            player_1.vacc = True
            vaccination_check = False
            break
        elif vaccined.upper() == 'NO':
            print('Sorry, you can not access the premises ! ')
            vaccination_check = False
            game_on = False
            request_drink_check = False
            banned_player_list.append(client_check)
            player_1.vacc = False
            break 
    except:
        print('You must respond *YES* or *NO*')
        vaccination_check = True

              
else:
    print('Printemps')
    pass
         
request_drink_check = True
game_on = True      
      
while True:
    if game_on == False:
        break
    elif player_1.vacc == False:
        break
      
    else:
        while request_drink_check:
            try:
                d = input('\n It appeared you have ordered already ?' + '*YES* or *NO*'+ '\n')
                if d.upper() == 'YES':
                    print('Perfect , your command is processing..' + '\n')
                    print('...' + player_1.type_drink.title() +' coming..' + '\n')
                    dealer_1.take_order(player_1.type_drink)
                    print('                                ')
                    print('                                ')
                    print(hand_1.show_player(player_1.name,player_1.account_balance))
                    request_drink_check = False
                    game_on = True
                    break
#                     dealer_1.show_drinks()
#                     order_drink = input('What would you prefer in the list Above\n')
#                     if order_drink in drink_descs:
                        
            
                    
         
                
                
                else: 
                    if d.upper() == 'NO':
                        select_drink =  True
                        while select_drink:
                            try:
                                dealer_1.show_drinks()
                                which_drink = input('Sorry , which one from the List  ?' + '\n')
                                for drink_desc in drink_descs:
#                                     for drink_desc in drink_descs:
                                    if which_drink == drink_desc:
                                        player_info = Player(player_1.name,player_1.account_balance,player_1.drink,which_drink, player_1.vacc)
                            #print(drink_prices[player_info.type_drink])
                                        player_1.reduce_balance(drink_prices[which_drink])
                                        
                                        print('Perfect , your command is processing..')
                                        print('... ' + which_drink.title() +' is coming..' + '\n')
                                        dealer_1.take_order(which_drink)
                                        print('                                ')
                                        print('                                ')
                                        print(hand_1.show_player(player_1.name,player_1.account_balance))
                                        select_drink = False
                                        request_drink_check = False
                                        game_on = True
                                        break
                                    else:
                                        select_drink = True
#                                         print('You must choose from the List ' + '\n')
                                        pass
                            except(ValueError,TypeError):
                                print('The type is Wrong '  + '\n')
                                
                
                    
                    
                
    
            except(ValueError,TypeError):
                print('Whoops ! Please answer *YES* or *NO*')
                request_drink_check = True
     
            
# ready_check = False
    bust_check = False
    while game_on:
        player_check = True
    
 
        new_deck = Deck()
        new_deck.shuffle() 
      
      
        

        if game_on:
#             count_game += 1
            try:
                answer = replay()
                if answer == False:
                    game_on = False
                    print(player_1.name + ' you ended up with  ' + str(chips) + ' chips ' + '\n')
                    print('Exchanging as per rates below...')
                    print('...' + '\n')
                    dealer_1.show_rates()
                    print('Black Jack Abidjan 🇨🇮 club wish you amazing evening and Hope to see you soon ! ' + '\n')
                    if chips < 0:
                        print(hand_1.show_player(player_1.name,player_1.account_balance))
                        break
                    elif chips in list(range(0,1501)):
                        player_1.add_balance(3*chips)
                        print(hand_1.show_player(player_1.name,player_1.account_balance))
                        break
                    else:
                        player_1.add_balance(2*chips)
                        print(hand_1.show_player(player_1.name,player_1.account_balance))
                        break
                        
                else:        
                        

                    
                    
                    count_game += 1
                    print(player_1.name + ' you currently have ' + str(chips) + ' chips ' + '\n')
                    print('Game ' + str(count_game) + '\n')
#                     bet = take_bet(player_1.name)
#                     if count_game >=1:
                    
                    bet = take_bet(chips)
    
#                     bet = take_bet(chip_1)
#     

#                     bet = int(input('How many chips Bet for game  ')) 
#                     print('\n')
#                     if bet > chips:
#                         too_much = True
#                         print('Hi, ' + player_1.name + ' You do not have enough chips, you currently have ' + str(chips) + ' chips' + +'\n')
#                         while too_much:
#                             try:
#                                 bet = int(input('How many chips Bet for game  ')) 
#                                 print('\n')
#                                 print('\n'+'Je suis la ')
#                                 if bet > chips:
#                                     print('Hi, ' + player_1.name + ' You do not have enough chips, you currently have ' + str(chips) + ' chips' + +'\n')
#                                     too_much = True
#                                 else:
#                                     count_game = 0
#                                     too_much = False
#                                     break

#                             except:
#                                 print('Please choose a Number  3555')
#                     else:        
#                         left_chips = chips - bet
                    print('Game '  + str(count_game) + '\n' )
                    print('----------Cards on the table-------------')
                    print('Distributing...')
                    print('...' + '\n')

                    count_win = 0
                    count_lost = 0
                    hand_1.add_card(new_deck.deal_one())
                    dealer_1.add_dealer_hand_card(new_deck.deal_one())
                    print(dealer_1.show_dealer_hand())
                    hand_1.add_card(new_deck.deal_one())
                    dealer_1.add_dealer_hand_card(new_deck.deal_one())
                    print(hand_1.show_player(player_1.name,player_1.account_balance))

                    while player_check:
                        if bust_check or hand_1.check_busst(player_1.name):
#                             print('Game ' + str(count_game) + ' Over' + '\n')
                #                                         Reset hands after a Game
                            hand_1.reset_player_hand()
                            dealer_1.reset_dealer_hand()
        #                             game_on = False

                            chip_1 = Chips(chips,bet)
                            chips = chip_1.loose_bet()
                            break

                        elif  dealer_1.computer_busst(): 
                            print('Game ' + str(count_game) + ' Over' + '\n')
        #                                         Reset hands after a Game
                            hand_1.reset_player_hand()
                            dealer_1.reset_dealer_hand()                            
        #                             game_on = False

                            chip_1 = Chips(chips,bet)
                            chips = chip_1.win_bet()
                            print('\n' + 'Merci')
                            break

                        else:
                            try:
                                if hand_1.check_busst(player_1.name) or dealer_1.computer_busst():
                                    break
                                else: 
                                    if count_win >0 or count_lost > 0:
                                        count_win = 0
                                        count_lost = 0
                                        break
                                    else:
                                        
                                        q = input('Would you like to Hit or stay ? Choose *H* or *S*')
                                        if q.upper() == 'H':
                                            hand_1.add_card(new_deck.deal_one())
                                            while hand_1.check_busst(player_1.name):
                                                print('Game ' + str(count_game) + ' Over' + '\n')

                                                print(hand_1.show_player(player_1.name,player_1.account_balance))
                                                print(dealer_1.show_dealer_hand())
                                                print('\t' + 'Yorobo')

            #                                         Reset hands after a Game
        #                                             hand_1.reset_player_hand()
        #                                             dealer_1.reset_dealer_hand()

        #                                             chip_1 = Chips(chips,bet)
        #                                             chips = chip_1.loose_bet(player_1.name)
                                                count_lost +=1

                                                break
                                            else:
                                                if hand_1.player_value_sum() > dealer_1.dealer_value_sum():
                                                    print('\n')
                                                    print('Game ' + str(count_game) + ' Over' + '\n')
                                                    print('Player ' + player_1.name + ' wins against Dealer' + '\n')

                #                                             print(player_1.name 
                                                    print(hand_1.show_player(player_1.name,player_1.account_balance))
                                                    print(dealer_1.show_dealer_hand())

                                                    hand_1.reset_player_hand()
                                                    dealer_1.reset_dealer_hand()

                                                    chip_1 = Chips(chips,bet)
                                                    chips = chip_1.win_bet()
                                                    count_win +=1
                                                    print('\t' + 'Zoumia')
                                                    break
                                                elif hand_1.player_value_sum() < dealer_1.dealer_value_sum():
                                                    print('\n')
                                                    print('Game ' + str(count_game) + ' Over' + '\n')
                                                    print('Player ' + player_1.name + ' looses against Dealer' + '\n')


                                                    print(dealer_1.show_dealer_hand())
                                                    print(hand_1.show_player(player_1.name,player_1.account_balance))
                                                    hand_1.reset_player_hand()
                                                    dealer_1.reset_dealer_hand()

                                                    chip_1 = Chips(chips,bet)
                                                    chips = chip_1.loose_bet()
                                                    print('\t' + 'Coro Abou')
                                                    count_lost +=1
                                                    break

                                        elif q.upper() == 'S':
                                            while hand_1.check_busst(player_1.name) or dealer_1.computer_busst():
                                                if hand_1.check_busst(player_1.name):
                                                    print('Game ' + str(count_game) + ' Over' + '\n')



                                                    print(dealer_1.show_dealer_hand())
                                                    print(hand_1.show_player(player_1.name,player_1.account_balance))

                                                    hand_1.reset_player_hand()
                                                    dealer_1.reset_dealer_hand() 

                                                    chip_1 = Chips(chips,bet)
                                                    chips = chip_1.loose_bet()
                                                    print('\t' + ' Ouzouma')
                                                    count_lost +=1
                                                    break
                                                else:
                                                    print('Game ' + str(count_game) + ' Over' + '\n')

                                                    print(hand_1.show_player(player_1.name,player_1.account_balance))
                                                    print(dealer_1.show_dealer_hand())




                                                    hand_1.reset_player_hand()
                                                    dealer_1.reset_dealer_hand()

                                                    chip_1 = Chips(chips,bet)
                                                    chips = chip_1.win_bet()
                                                    print( '\t' +'Oye-Nana')
                                                    count_win +=1
                                                    break

            #                                         game_on = False

                                            else:
                                                while not dealer_1.computer_busst():
                                                    while hand_1.player_value_sum() > dealer_1.dealer_value_sum():
                                                        dealer_1.add_dealer_hand_card(new_deck.deal_one())
                                                    else:
                                                        if dealer_1.computer_busst():
                #                                                 print('Game ' + str(count_game) + ' Over' + '\n')

                                                            print(hand_1.show_player(player_1.name,player_1.account_balance))
                                                            print(dealer_1.show_dealer_hand())


                #                                                 hand_1.reset_player_hand()
                #                                                 dealer_1.reset_dealer_hand()

                #                                                 chip_1 = Chips(chips,bet)
                #                                                 chips = chip_1.win_bet(player_1.name)
                                                            print( '\t' +'Walllloo')
                                                            count_win += 1
                                                            break



        #                                                 elif hand_1.player_value_sum() < dealer_1.dealer_value_sum():
        #                                                     print('Game ' + str(count_game) + ' Over' + '\n')

        #                                                     print(hand_1.show_player(player_1.name,player_1.account_balance))
        #                                                     print(dealer_1.show_dealer_hand())

        #                                                     hand_1.reset_player_hand()
        #                                                     dealer_1.reset_dealer_hand()

        #                                                     chip_1 = Chips(chips,bet)
        #                                                     chips = chip_1.loose_bet(player_1.name)
        #                                                     print('\n'+'belelou!')
        #                                                     break

        #                                                 elif hand_1.player_value_sum() > dealer_1.dealer_value_sum():
        #                                                     print('Game ' + str(count_game) + ' Over' + '\n')

        #                                                     print(hand_1.show_player(player_1.name,player_1.account_balance))
        #                                                     print(dealer_1.show_dealer_hand())

        #                                                     hand_1.reset_player_hand()
        #                                                     dealer_1.reset_dealer_hand()

        #                                                     chip_1 = Chips(chips,bet)
        #                                                     chips = chip_1.win_bet(player_1.name)
        #                                                     print('\t' + 'heyyyy')
        #                                                     break






                                                else:
#                                                     print('\t'+'Par ici')
                                                    break




#                                             else:
#                                                 print('Game ' + str(count_game) + ' Over' + '\n')

#                                                 print(hand_1.show_player(player_1.name,player_1.account_balance))
#                                                 print(dealer_1.show_dealer_hand())


#         #                                             hand_1.reset_player_hand()
#         #                                             dealer_1.reset_dealer_hand()

#         #                                             chip_1 = Chips(chips,bet)
#         #                                             chips = chip_1.win_bet(player_1.name)
#                                                 print( '\t' +'Wahoo')

#                                                 break

                                        #if len(player_1.)



                            except ValueError:
                                print('You must pick in between choose *H* or *S* &&&')
            except ValueError:
                print('Please Choose a Number 3433')
# Out:
# ---------------------------------------------------------------
# Welcome to Black Jack Abidjan 🇨🇮 club 🎰 ♠️♥️♦️♣️!First Éditio
# ---------------------------------------------------------------
# ---- From 0 to 1500$ - 200 Chips
# ---- From 1500 to 3500$ - 500 Chips
# ---- After 3500$ - 800 Chips  ----
#
#
# How much the bid $$ ? 1300
# Please Note
#
# Here the rates exchange at the end of the Casino game :
#
# ------------------------------------
# ------------------------------------
#
# ---- From 0 to 1500 chips -  you triple your Chips
# ---- From 1500 chips and Above - you double your Chips
# ------------------------------------
# ------------------------------------
#
#
# Player Naomie has 0 cards. value of 0. Bank Account is 3700 $
#
# Naomie has now 200 chips /n
# Thanks ,see You can visit the Bar - Restaurant for exclusives Offers .
#
#
#
#
#
# -------  Important- VACCINATION IS MANDATORY in order to access Establishment -------------
# Are you VAXX ?? *YES* or *NO*yes
# ...

# %%
new_deck.
